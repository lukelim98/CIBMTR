# %%
import pandas as pd
import scipy.stats as stats
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
train_data = pd.read_csv('Data/train.csv')
test_data = pd.read_csv('Data/test.csv')
data_dict = pd.read_csv('Data/data_dictionary.csv')
sample_submission = pd.read_csv('Data/sample_submission.csv')

# %%
for column in train_data.columns:
    if column == 'ID':
        pass
    else:
        print(f"{train_data[column].value_counts(dropna=False)}")
        print()
# Out:
# dri_score
# Intermediate                                         10436
# N/A - pediatric                                       4779
# High                                                  4701
# N/A - non-malignant indication                        2427
# TBD cytogenetics                                      2003
# Low                                                   1926
# High - TED AML case <missing cytogenetics             1414
# Intermediate - TED AML case <missing cytogenetics      481
# N/A - disease not classifiable                         272
# Very high                                              198
# NaN                                                    154
# Missing disease status                                   9
# Name: count, dtype: int64
#
# psych_disturb
# No          23005
# Yes          3587
# NaN          2062
# Not done      146
# Name: count, dtype: int64
#
# cyto_score
# Poor            8802
# NaN             8068
# Intermediate    6376
# Favorable       3011
# TBD             1341
# Normal           643
# Other            504
# Not tested        55
# Name: count, dtype: int64
#
# diabetes
# No          22201
# Yes          4339
# NaN          2119
# Not done      141
# Name: count, dtype: int64
#
# hla_match_c_high
# 2.0    18565
# 1.0     5536
# NaN     4620
# 0.0       79
# Name: count, dtype: int64
#
# hla_high_res_8
# 8.0    13568
# NaN     5829
# 4.0     3820
# 7.0     2385
# 5.0     1648
# 6.0     1520
# 3.0       28
# 2.0        2
# Name: count, dtype: int64
#
# tbi_status
# No TBI                              18861
# TBI + Cy +- Other                    6104
# TBI +- Other, <=cGy                  1727
# TBI +- Other, >cGy                   1700
# TBI +- Other, -cGy, single            134
# TBI +- Other, -cGy, fractionated      119
# TBI +- Other, -cGy, unknown dose       79
# TBI +- Other, unknown dose             76
# Name: count, dtype: int64
#
# arrhythmia
# No          25203
# NaN          2202
# Yes          1277
# Not done      118
# Name: count, dtype: int64
#
# hla_low_res_6
# 6.0    15690
# 3.0     4955
# NaN     3270
# 5.0     2808
# 4.0     2055
# 2.0       22
# Name: count, dtype: int64
#
# graft_type
# Peripheral blood    20546
# Bone marrow          8254
# Name: count, dtype: int64
#
# vent_hist
# No     27721
# Yes      820
# NaN      259
# Name: count, dtype: int64
#
# renal_issue
# No          26548
# NaN          1915
# Yes           200
# Not done      137
# Name: count, dtype: int64
#
# pulm_severe
# No          24779
# NaN          2135
# Yes          1706
# Not done      180
# Name: count, dtype: int64
#
# prim_disease_hct
# ALL                     8102
# AML                     7135
# MDS                     3046
# IPA                     1719
# MPN                     1656
# IEA                     1449
# NHL                     1319
# IIS                     1024
# PCD                      869
# SAA                      713
# AI                       449
# HIS                      445
# Other leukemia           366
# Solid tumor              207
# IMD                      144
# Other acute leukemia      83
# HD                        54
# CML                       20
# Name: count, dtype: int64
#
# hla_high_res_6
# 6.0    14022
# NaN     5284
# 3.0     4596
# 5.0     2726
# 4.0     2128
# 2.0       43
# 0.0        1
# Name: count, dtype: int64
#
# cmv_status
# +/+    13596
# -/+     7081
# +/-     4048
# -/-     3441
# NaN      634
# Name: count, dtype: int64
#
# hla_high_res_10
# 10.0    12232
# NaN      7163
# 5.0      3161
# 9.0      2369
# 6.0      1355
# 8.0      1314
# 7.0      1180
# 4.0        25
# 3.0         1
# Name: count, dtype: int64
#
# hla_match_dqb1_high
# 2.0    17468
# 1.0     6056
# NaN     5199
# 0.0       77
# Name: count, dtype: int64
#
# tce_imm_match
# P/P    13114
# NaN    11133
# G/G     2522
# H/H     1084
# G/B      544
# H/B      229
# P/H       83
# P/B       66
# P/G       25
# Name: count, dtype: int64
#
# hla_nmdp_6
# 6.0    15105
# 3.0     4888
# NaN     4197
# 5.0     3296
# 4.0     1279
# 2.0       35
# Name: count, dtype: int64
#
# hla_match_c_low
# 2.0    19782
# 1.0     6139
# NaN     2800
# 0.0       79
# Name: count, dtype: int64
#
# rituximab
# No     26033
# NaN     2148
# Yes      619
# Name: count, dtype: int64
#
# hla_match_drb1_low
# 2.0    18710
# 1.0     7447
# NaN     2643
# Name: count, dtype: int64
#
# hla_match_dqb1_low
# 2.0    19131
# 1.0     5384
# NaN     4194
# 0.0       91
# Name: count, dtype: int64
#
# prod_type
# PB    20381
# BM     8419
# Name: count, dtype: int64
#
# cyto_score_detail
# NaN             11923
# Intermediate    11158
# Poor             3323
# Favorable        1208
# TBD              1043
# Not tested        145
# Name: count, dtype: int64
#
# conditioning_intensity
# MAC                              12288
# RIC                               7722
# NaN                               4789
# NMA                               3479
# TBD                                373
# No drugs reported                   87
# N/A, F(pre-TED) not submitted       62
# Name: count, dtype: int64
#
# ethnicity
# Not Hispanic or Latino      24482
# Hispanic or Latino           3347
# NaN                           587
# Non-resident of the U.S.      384
# Name: count, dtype: int64
#
# year_hct
# 2018    7336
# 2016    5049
# 2017    4830
# 2008    2544
# 2015    2243
# 2013    1871
# 2012    1571
# 2014    1098
# 2019     774
# 2011     599
# 2009     503
# 2010     378
# 2020       4
# Name: count, dtype: int64
#
# obesity
# No          25144
# Yes          1779
# NaN          1760
# Not done      117
# Name: count, dtype: int64
#
# mrd_hct
# NaN         16597
# Negative     8068
# Positive     4135
# Name: count, dtype: int64
#
# in_vivo_tcd
# No     17591
# Yes    10984
# NaN      225
# Name: count, dtype: int64
#
# tce_match
# NaN                   18996
# Permissive             6272
# GvH non-permissive     1605
# Fully matched          1059
# HvG non-permissive      868
# Name: count, dtype: int64
#
# hla_match_a_high
# 2.0    17304
# 1.0     7132
# NaN     4301
# 0.0       63
# Name: count, dtype: int64
#
# hepatic_severe
# No          25238
# NaN          1871
# Yes          1481
# Not done      210
# Name: count, dtype: int64
#
# donor_age
# NaN       1808
# 23.570       7
# 24.504       6
# 25.378       6
# 38.722       5
#           ...
# 62.419       1
# 65.529       1
# 63.902       1
# 66.677       1
# 30.571       1
# Name: count, Length: 20910, dtype: int64
#
# prior_tumor
# No          23828
# Yes          3009
# NaN          1678
# Not done      285
# Name: count, dtype: int64
#
# hla_match_b_low
# 2.0    18951
# 1.0     7220
# NaN     2565
# 0.0       64
# Name: count, dtype: int64
#
# peptic_ulcer
# No          25956
# NaN          2419
# Yes           259
# Not done      166
# Name: count, dtype: int64
#
# age_at_hct
# 0.044     1005
# 64.470       6
# 15.820       6
# 63.701       5
# 65.184       5
#           ...
# 52.191       1
# 34.487       1
# 42.467       1
# 21.377       1
# 13.988       1
# Name: count, Length: 22168, dtype: int64
#
# hla_match_a_low
# 2.0    18776
# 1.0     7585
# NaN     2390
# 0.0       49
# Name: count, dtype: int64
#
# gvhd_proph
# FK+ MMF +- others                  10440
# Cyclophosphamide alone              5270
# FK+ MTX +- others(not MMF)          4262
# Cyclophosphamide +- others          2369
# CSA + MMF +- others(not FK)         2278
# FKalone                             1230
# Other GVHD Prophylaxis               550
# TDEPLETION alone                     545
# TDEPLETION +- other                  539
# No GvHD Prophylaxis                  262
# CDselect alone                       251
# NaN                                  225
# CSA + MTX +- others(not MMF,FK)      224
# CSA alone                            214
# Parent Q = yes, but no agent          62
# CDselect +- other                     55
# CSA +- others(not FK,MMF,MTX)         23
# FK+- others(not MMF,MTX)               1
# Name: count, dtype: int64
#
# rheum_issue
# No          26015
# NaN          2183
# Yes           457
# Not done      145
# Name: count, dtype: int64
#
# sex_match
# M-M    7980
# F-M    7822
# M-F    6715
# F-F    6022
# NaN     261
# Name: count, dtype: int64
#
# hla_match_b_high
# 2.0    17366
# 1.0     7269
# NaN     4088
# 0.0       77
# Name: count, dtype: int64
#
# race_group
# More than one race                           4845
# Asian                                        4832
# White                                        4831
# Black or African-American                    4795
# American Indian or Alaska Native             4790
# Native Hawaiian or other Pacific Islander    4707
# Name: count, dtype: int64
#
# comorbidity_score
# 0.0     10738
# 2.0      5899
# 1.0      4852
# 3.0      2460
# 4.0      1396
# 5.0      1219
# 6.0       708
# 7.0       492
# NaN       477
# 8.0       293
# 9.0       190
# 10.0       76
# Name: count, dtype: int64
#
# karnofsky_score
# 90.0     15336
# 70.0      6690
# 100.0     2476
# 80.0      2036
# 60.0      1291
# NaN        870
# 50.0        91
# 40.0        10
# Name: count, dtype: int64
#
# hepatic_mild
# No          24989
# NaN          1917
# Yes          1754
# Not done      140
# Name: count, dtype: int64
#
# tce_div_match
# Permissive mismatched            12936
# NaN                              11396
# GvH non-permissive                2458
# HvG non-permissive                1417
# Bi-directional non-permissive      593
# Name: count, dtype: int64
#
# donor_related
# Related                     16208
# Unrelated                   12088
# Multiple donor (non-UCB)      346
# NaN                           158
# Name: count, dtype: int64
#
# melphalan_dose
# N/A, Mel not given    20135
# MEL                    7260
# NaN                    1405
# Name: count, dtype: int64
#
# hla_low_res_8
# 8.0    15160
# 4.0     4259
# NaN     3653
# 7.0     2603
# 5.0     1613
# 6.0     1488
# 3.0       23
# 2.0        1
# Name: count, dtype: int64
#
# cardiac
# No          24592
# NaN          2542
# Yes          1519
# Not done      147
# Name: count, dtype: int64
#
# hla_match_drb1_high
# 2.0    18066
# 1.0     7311
# NaN     3352
# 0.0       71
# Name: count, dtype: int64
#
# pulm_moderate
# No          21338
# Yes          5249
# NaN          2047
# Not done      166
# Name: count, dtype: int64
#
# hla_low_res_10
# 10.0    13734
# NaN      5064
# 5.0      3211
# 9.0      2544
# 6.0      1664
# 8.0      1387
# 7.0      1170
# 4.0        26
# Name: count, dtype: int64
#
# efs
# 1.0    15532
# 0.0    13268
# Name: count, dtype: int64
#
# efs_time
# 5.697     10
# 5.643     10
# 5.801      9
# 5.608      9
# 5.886      9
#           ..
# 4.430      1
# 19.391     1
# 23.336     1
# 36.169     1
# 25.158     1
# Name: count, Length: 19208, dtype: int64

# %%
train_data.columns
# Out:
# Index(['ID', 'dri_score', 'psych_disturb', 'cyto_score', 'diabetes',
#        'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia',
#        'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue',
#        'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status',
#        'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6',
#        'hla_match_c_low', 'rituximab', 'hla_match_drb1_low',
#        'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail',
#        'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct',
#        'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe',
#        'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer',
#        'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue',
#        'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score',
#        'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related',
#        'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high',
#        'pulm_moderate', 'hla_low_res_10', 'efs', 'efs_time'],
#       dtype='object')

# %%
data_dict
# Out:
#                   variable                                        description  \
# 0                dri_score                         Refined disease risk index
# 1            psych_disturb                            Psychiatric disturbance
# 2               cyto_score                                  Cytogenetic score
# 3                 diabetes                                           Diabetes
# 4         hla_match_c_high  Recipient / 1st donor allele level (high resol...
# 5           hla_high_res_8  Recipient / 1st donor allele-level (high resol...
# 6               tbi_status                                                TBI
# 7               arrhythmia                                         Arrhythmia
# 8            hla_low_res_6  Recipient / 1st donor antigen-level (low resol...
# 9               graft_type                                         Graft type
# 10               vent_hist                  History of mechanical ventilation
# 11             renal_issue                           Renal, moderate / severe
# 12             pulm_severe                                  Pulmonary, severe
# 13        prim_disease_hct                            Primary disease for HCT
# 14          hla_high_res_6  Recipient / 1st donor allele-level (high resol...
# 15              cmv_status                     Donor/recipient CMV serostatus
# 16         hla_high_res_10  Recipient / 1st donor allele-level (high resol...
# 17     hla_match_dqb1_high  Recipient / 1st donor allele level (high resol...
# 18           tce_imm_match      T-cell epitope immunogenicity/diversity match
# 19              hla_nmdp_6  Recipient / 1st donor matching at HLA-A(lo),-B...
# 20         hla_match_c_low  Recipient / 1st donor antigen level (low resol...
# 21               rituximab                    Rituximab given in conditioning
# 22      hla_match_drb1_low  Recipient / 1st donor antigen level (low resol...
# 23      hla_match_dqb1_low  Recipient / 1st donor antigen level (low resol...
# 24               prod_type                                       Product type
# 25       cyto_score_detail                     Cytogenetics for DRI (AML/MDS)
# 26  conditioning_intensity            Computed planned conditioning intensity
# 27               ethnicity                                          Ethnicity
# 28                year_hct                                        Year of HCT
# 29                 obesity                                            Obesity
# 30                 mrd_hct                       MRD at time of HCT (AML/ALL)
# 31             in_vivo_tcd         In-vivo T-cell depletion (ATG/alemtuzumab)
# 32               tce_match                            T-cell epitope matching
# 33        hla_match_a_high  Recipient / 1st donor allele level (high resol...
# 34          hepatic_severe                         Hepatic, moderate / severe
# 35               donor_age                                          Donor age
# 36             prior_tumor                                 Solid tumor, prior
# 37         hla_match_b_low  Recipient / 1st donor antigen level (low resol...
# 38            peptic_ulcer                                       Peptic ulcer
# 39              age_at_hct                                         Age at HCT
# 40         hla_match_a_low  Recipient / 1st donor antigen level (low resol...
# 41              gvhd_proph                           Planned GVHD prophylaxis
# 42             rheum_issue                                      Rheumatologic
# 43               sex_match                          Donor/recipient sex match
# 44        hla_match_b_high  Recipient / 1st donor allele level (high resol...
# 45              race_group                                               Race
# 46       comorbidity_score                           Sorror comorbidity score
# 47         karnofsky_score                                         KPS at HCT
# 48            hepatic_mild                                      Hepatic, mild
# 49           tce_div_match                            T-cell epitope matching
# 50           donor_related                        Related vs. unrelated donor
# 51          melphalan_dose                            Melphalan dose (mg/m^2)
# 52           hla_low_res_8  Recipient / 1st donor antigen-level (low resol...
# 53                 cardiac                                            Cardiac
# 54     hla_match_drb1_high  Recipient / 1st donor allele level (high resol...
# 55           pulm_moderate                                Pulmonary, moderate
# 56          hla_low_res_10                                                NaN
# 57                     efs                                Event-free survival
# 58                efs_time                Time to event-free survival, months
#
#            type                                             values
# 0   Categorical  ['Intermediate' 'High' 'N/A - non-malignant in...
# 1   Categorical                        ['Yes' 'No' nan 'Not done']
# 2   Categorical  ['Intermediate' 'Favorable' 'Poor' 'TBD' nan '...
# 3   Categorical                        ['No' 'Yes' nan 'Not done']
# 4     Numerical                                                NaN
# 5     Numerical                                                NaN
# 6   Categorical  ['No TBI' 'TBI + Cy +- Other' 'TBI +- Other, <...
# 7   Categorical                        ['No' nan 'Yes' 'Not done']
# 8     Numerical                                                NaN
# 9   Categorical                 ['Peripheral blood' 'Bone marrow']
# 10  Categorical                                   ['No' 'Yes' nan]
# 11  Categorical                        ['No' nan 'Yes' 'Not done']
# 12  Categorical                        ['No' 'Yes' nan 'Not done']
# 13  Categorical  ['ALL' 'MPN' 'IPA' 'AML' 'MDS' 'Other acute le...
# 14    Numerical                                                NaN
# 15  Categorical                      ['+/-' '+/+' '-/-' '-/+' nan]
# 16    Numerical                                                NaN
# 17    Numerical                                                NaN
# 18  Categorical  ['P/P' nan 'G/G' 'H/H' 'G/B' 'H/B' 'P/H' 'P/G'...
# 19    Numerical                                                NaN
# 20    Numerical                                                NaN
# 21  Categorical                                   ['No' 'Yes' nan]
# 22    Numerical                                                NaN
# 23    Numerical                                                NaN
# 24  Categorical                                        ['PB' 'BM']
# 25  Categorical  ['Intermediate' nan 'TBD' 'Favorable' 'Poor' '...
# 26  Categorical  ['RIC' nan 'NMA' 'MAC' 'TBD' 'No drugs reporte...
# 27  Categorical  ['Not Hispanic or Latino' 'Hispanic or Latino'...
# 28    Numerical                                                NaN
# 29  Categorical                        ['No' 'Yes' nan 'Not done']
# 30  Categorical                        [nan 'Negative' 'Positive']
# 31  Categorical                                   ['Yes' 'No' nan]
# 32  Categorical  ['Permissive' 'Fully matched' nan 'GvH non-per...
# 33    Numerical                                                NaN
# 34  Categorical                        ['No' nan 'Yes' 'Not done']
# 35    Numerical                                                NaN
# 36  Categorical                        ['Yes' 'No' nan 'Not done']
# 37    Numerical                                                NaN
# 38  Categorical                        ['No' nan 'Yes' 'Not done']
# 39    Numerical                                                NaN
# 40    Numerical                                                NaN
# 41  Categorical  ['FK+ MMF +- others' 'Parent Q = yes, but no a...
# 42  Categorical                        ['No' nan 'Yes' 'Not done']
# 43  Categorical                      ['M-M' 'F-F' 'F-M' 'M-F' nan]
# 44    Numerical                                                NaN
# 45  Categorical  ['White' 'Black or African-American'\n 'Native...
# 46    Numerical                                                NaN
# 47    Numerical                                                NaN
# 48  Categorical                        ['No' 'Yes' nan 'Not done']
# 49  Categorical  ['Permissive mismatched' 'Bi-directional non-p...
# 50  Categorical  ['Unrelated' 'Related' 'Multiple donor (non-UC...
# 51  Categorical                   ['N/A, Mel not given' 'MEL' nan]
# 52    Numerical                                                NaN
# 53  Categorical                        ['No' 'Yes' nan 'Not done']
# 54    Numerical                                                NaN
# 55  Categorical                        ['Yes' 'Not done' 'No' nan]
# 56    Numerical                                                NaN
# 57  Categorical                              ['Event' 'Censoring']
# 58    Numerical                                                NaN

# %%
# Check correlation for numerical columns
correlations = train_data.corr(numeric_only=True)['efs'].sort_values(ascending=False)
correlations
# Out:
# efs                    1.000000
# age_at_hct             0.227866
# comorbidity_score      0.145723
# hla_match_drb1_high    0.074446
# hla_match_drb1_low     0.067485
# hla_high_res_10        0.048431
# donor_age              0.047566
# hla_low_res_6          0.047007
# hla_high_res_6         0.045261
# hla_high_res_8         0.044224
# hla_low_res_10         0.041972
# hla_match_b_low        0.040965
# hla_low_res_8          0.040612
# hla_nmdp_6             0.040145
# hla_match_dqb1_high    0.039736
# hla_match_dqb1_low     0.032440
# hla_match_c_high       0.031850
# hla_match_b_high       0.026293
# hla_match_c_low        0.016335
# hla_match_a_high       0.015881
# hla_match_a_low        0.015086
# ID                    -0.003517
# karnofsky_score       -0.091156
# year_hct              -0.106419
# efs_time              -0.741042
# Name: efs, dtype: float64

# %%
# Statistical Test for categorical variables
# low p-value suggest a relationship between the categorical column and efs
for col in train_data.columns:
    if col != 'efs' and train_data[col].dtype == 'object':
        contingency = pd.crosstab(train_data[col], train_data['efs'])
        chi2, p, dof, expected = stats.chi2_contingency(contingency)
        print(f"{col}: p-value={p}")
# Out:
# dri_score: p-value=0.0
# psych_disturb: p-value=1.2979884206277078e-26
# cyto_score: p-value=0.0017695925410587407
# diabetes: p-value=9.473517746062939e-31
# tbi_status: p-value=3.872202121618803e-17
# arrhythmia: p-value=1.4455281691857336e-13
# graft_type: p-value=0.0
# vent_hist: p-value=0.5894941475545321
# renal_issue: p-value=0.0008044609682586662
# pulm_severe: p-value=1.1740716320072957e-38
# prim_disease_hct: p-value=0.0
# cmv_status: p-value=2.9962065563817596e-63
# tce_imm_match: p-value=0.0034450120733785987
# rituximab: p-value=0.38833316629745207
# prod_type: p-value=0.0
# cyto_score_detail: p-value=2.2303455266813332e-39
# conditioning_intensity: p-value=8.244812565600893e-75
# ethnicity: p-value=1.3456203538403933e-12
# obesity: p-value=3.0830353189626647e-11
# mrd_hct: p-value=0.002937508875019472
# in_vivo_tcd: p-value=2.2959109320915427e-169
# tce_match: p-value=7.401409152266494e-06
# hepatic_severe: p-value=1.5564351873948503e-43
# prior_tumor: p-value=1.6392138057148511e-59
# peptic_ulcer: p-value=7.371145089197224e-05
# gvhd_proph: p-value=4.4419207490855484e-176
# rheum_issue: p-value=0.14867597064259122
# sex_match: p-value=2.4603059525281462e-45
# race_group: p-value=1.3172052971466758e-58
# hepatic_mild: p-value=0.007129012219444484
# tce_div_match: p-value=1.8542188641433064e-05
# donor_related: p-value=1.6828825555310805e-08
# melphalan_dose: p-value=0.30488476968458444
# cardiac: p-value=6.73553708148004e-60
# pulm_moderate: p-value=5.503403843282742e-30

# %% [markdown]
# # Handling NaN values

# %%
for col in train_data.columns:
    if col == 'ID':
        continue
    elif col != 'efs' and train_data[col].dtype == 'object':
        # Fill missing value with 'Missing'
        train_data[col].fillna('Missing', inplace=True)
    elif pd.api.types.is_numeric_dtype(train_data[col]):
        # Calculate the mode of the column
        mode_value = train_data[col].mode().iloc[0]
        train_data[col].fillna(mode_value, inplace=True)

# %%
for column in train_data.columns:
    if column == 'ID':
        pass
    else:
        print(f"{train_data[column].value_counts(dropna=False)}")
        print()
# Out:
# dri_score
# Intermediate                                         10436
# N/A - pediatric                                       4779
# High                                                  4701
# N/A - non-malignant indication                        2427
# TBD cytogenetics                                      2003
# Low                                                   1926
# High - TED AML case <missing cytogenetics             1414
# Intermediate - TED AML case <missing cytogenetics      481
# N/A - disease not classifiable                         272
# Very high                                              198
# Missing                                                154
# Missing disease status                                   9
# Name: count, dtype: int64
#
# psych_disturb
# No          23005
# Yes          3587
# Missing      2062
# Not done      146
# Name: count, dtype: int64
#
# cyto_score
# Poor            8802
# Missing         8068
# Intermediate    6376
# Favorable       3011
# TBD             1341
# Normal           643
# Other            504
# Not tested        55
# Name: count, dtype: int64
#
# diabetes
# No          22201
# Yes          4339
# Missing      2119
# Not done      141
# Name: count, dtype: int64
#
# hla_match_c_high
# 2.0    23185
# 1.0     5536
# 0.0       79
# Name: count, dtype: int64
#
# hla_high_res_8
# 8.0    19397
# 4.0     3820
# 7.0     2385
# 5.0     1648
# 6.0     1520
# 3.0       28
# 2.0        2
# Name: count, dtype: int64
#
# tbi_status
# No TBI                              18861
# TBI + Cy +- Other                    6104
# TBI +- Other, <=cGy                  1727
# TBI +- Other, >cGy                   1700
# TBI +- Other, -cGy, single            134
# TBI +- Other, -cGy, fractionated      119
# TBI +- Other, -cGy, unknown dose       79
# TBI +- Other, unknown dose             76
# Name: count, dtype: int64
#
# arrhythmia
# No          25203
# Missing      2202
# Yes          1277
# Not done      118
# Name: count, dtype: int64
#
# hla_low_res_6
# 6.0    18960
# 3.0     4955
# 5.0     2808
# 4.0     2055
# 2.0       22
# Name: count, dtype: int64
#
# graft_type
# Peripheral blood    20546
# Bone marrow          8254
# Name: count, dtype: int64
#
# vent_hist
# No         27721
# Yes          820
# Missing      259
# Name: count, dtype: int64
#
# renal_issue
# No          26548
# Missing      1915
# Yes           200
# Not done      137
# Name: count, dtype: int64
#
# pulm_severe
# No          24779
# Missing      2135
# Yes          1706
# Not done      180
# Name: count, dtype: int64
#
# prim_disease_hct
# ALL                     8102
# AML                     7135
# MDS                     3046
# IPA                     1719
# MPN                     1656
# IEA                     1449
# NHL                     1319
# IIS                     1024
# PCD                      869
# SAA                      713
# AI                       449
# HIS                      445
# Other leukemia           366
# Solid tumor              207
# IMD                      144
# Other acute leukemia      83
# HD                        54
# CML                       20
# Name: count, dtype: int64
#
# hla_high_res_6
# 6.0    19306
# 3.0     4596
# 5.0     2726
# 4.0     2128
# 2.0       43
# 0.0        1
# Name: count, dtype: int64
#
# cmv_status
# +/+        13596
# -/+         7081
# +/-         4048
# -/-         3441
# Missing      634
# Name: count, dtype: int64
#
# hla_high_res_10
# 10.0    19395
# 5.0      3161
# 9.0      2369
# 6.0      1355
# 8.0      1314
# 7.0      1180
# 4.0        25
# 3.0         1
# Name: count, dtype: int64
#
# hla_match_dqb1_high
# 2.0    22667
# 1.0     6056
# 0.0       77
# Name: count, dtype: int64
#
# tce_imm_match
# P/P        13114
# Missing    11133
# G/G         2522
# H/H         1084
# G/B          544
# H/B          229
# P/H           83
# P/B           66
# P/G           25
# Name: count, dtype: int64
#
# hla_nmdp_6
# 6.0    19302
# 3.0     4888
# 5.0     3296
# 4.0     1279
# 2.0       35
# Name: count, dtype: int64
#
# hla_match_c_low
# 2.0    22582
# 1.0     6139
# 0.0       79
# Name: count, dtype: int64
#
# rituximab
# No         26033
# Missing     2148
# Yes          619
# Name: count, dtype: int64
#
# hla_match_drb1_low
# 2.0    21353
# 1.0     7447
# Name: count, dtype: int64
#
# hla_match_dqb1_low
# 2.0    23325
# 1.0     5384
# 0.0       91
# Name: count, dtype: int64
#
# prod_type
# PB    20381
# BM     8419
# Name: count, dtype: int64
#
# cyto_score_detail
# Missing         11923
# Intermediate    11158
# Poor             3323
# Favorable        1208
# TBD              1043
# Not tested        145
# Name: count, dtype: int64
#
# conditioning_intensity
# MAC                              12288
# RIC                               7722
# Missing                           4789
# NMA                               3479
# TBD                                373
# No drugs reported                   87
# N/A, F(pre-TED) not submitted       62
# Name: count, dtype: int64
#
# ethnicity
# Not Hispanic or Latino      24482
# Hispanic or Latino           3347
# Missing                       587
# Non-resident of the U.S.      384
# Name: count, dtype: int64
#
# year_hct
# 2018    7336
# 2016    5049
# 2017    4830
# 2008    2544
# 2015    2243
# 2013    1871
# 2012    1571
# 2014    1098
# 2019     774
# 2011     599
# 2009     503
# 2010     378
# 2020       4
# Name: count, dtype: int64
#
# obesity
# No          25144
# Yes          1779
# Missing      1760
# Not done      117
# Name: count, dtype: int64
#
# mrd_hct
# Missing     16597
# Negative     8068
# Positive     4135
# Name: count, dtype: int64
#
# in_vivo_tcd
# No         17591
# Yes        10984
# Missing      225
# Name: count, dtype: int64
#
# tce_match
# Missing               18996
# Permissive             6272
# GvH non-permissive     1605
# Fully matched          1059
# HvG non-permissive      868
# Name: count, dtype: int64
#
# hla_match_a_high
# 2.0    21605
# 1.0     7132
# 0.0       63
# Name: count, dtype: int64
#
# hepatic_severe
# No          25238
# Missing      1871
# Yes          1481
# Not done      210
# Name: count, dtype: int64
#
# donor_age
# 23.570    1815
# 24.504       6
# 25.378       6
# 24.803       5
# 23.950       5
#           ...
# 62.419       1
# 65.529       1
# 63.902       1
# 66.677       1
# 30.571       1
# Name: count, Length: 20909, dtype: int64
#
# prior_tumor
# No          23828
# Yes          3009
# Missing      1678
# Not done      285
# Name: count, dtype: int64
#
# hla_match_b_low
# 2.0    21516
# 1.0     7220
# 0.0       64
# Name: count, dtype: int64
#
# peptic_ulcer
# No          25956
# Missing      2419
# Yes           259
# Not done      166
# Name: count, dtype: int64
#
# age_at_hct
# 0.044     1005
# 64.470       6
# 15.820       6
# 63.701       5
# 65.184       5
#           ...
# 52.191       1
# 34.487       1
# 42.467       1
# 21.377       1
# 13.988       1
# Name: count, Length: 22168, dtype: int64
#
# hla_match_a_low
# 2.0    21166
# 1.0     7585
# 0.0       49
# Name: count, dtype: int64
#
# gvhd_proph
# FK+ MMF +- others                  10440
# Cyclophosphamide alone              5270
# FK+ MTX +- others(not MMF)          4262
# Cyclophosphamide +- others          2369
# CSA + MMF +- others(not FK)         2278
# FKalone                             1230
# Other GVHD Prophylaxis               550
# TDEPLETION alone                     545
# TDEPLETION +- other                  539
# No GvHD Prophylaxis                  262
# CDselect alone                       251
# Missing                              225
# CSA + MTX +- others(not MMF,FK)      224
# CSA alone                            214
# Parent Q = yes, but no agent          62
# CDselect +- other                     55
# CSA +- others(not FK,MMF,MTX)         23
# FK+- others(not MMF,MTX)               1
# Name: count, dtype: int64
#
# rheum_issue
# No          26015
# Missing      2183
# Yes           457
# Not done      145
# Name: count, dtype: int64
#
# sex_match
# M-M        7980
# F-M        7822
# M-F        6715
# F-F        6022
# Missing     261
# Name: count, dtype: int64
#
# hla_match_b_high
# 2.0    21454
# 1.0     7269
# 0.0       77
# Name: count, dtype: int64
#
# race_group
# More than one race                           4845
# Asian                                        4832
# White                                        4831
# Black or African-American                    4795
# American Indian or Alaska Native             4790
# Native Hawaiian or other Pacific Islander    4707
# Name: count, dtype: int64
#
# comorbidity_score
# 0.0     11215
# 2.0      5899
# 1.0      4852
# 3.0      2460
# 4.0      1396
# 5.0      1219
# 6.0       708
# 7.0       492
# 8.0       293
# 9.0       190
# 10.0       76
# Name: count, dtype: int64
#
# karnofsky_score
# 90.0     16206
# 70.0      6690
# 100.0     2476
# 80.0      2036
# 60.0      1291
# 50.0        91
# 40.0        10
# Name: count, dtype: int64
#
# hepatic_mild
# No          24989
# Missing      1917
# Yes          1754
# Not done      140
# Name: count, dtype: int64
#
# tce_div_match
# Permissive mismatched            12936
# Missing                          11396
# GvH non-permissive                2458
# HvG non-permissive                1417
# Bi-directional non-permissive      593
# Name: count, dtype: int64
#
# donor_related
# Related                     16208
# Unrelated                   12088
# Multiple donor (non-UCB)      346
# Missing                       158
# Name: count, dtype: int64
#
# melphalan_dose
# N/A, Mel not given    20135
# MEL                    7260
# Missing                1405
# Name: count, dtype: int64
#
# hla_low_res_8
# 8.0    18813
# 4.0     4259
# 7.0     2603
# 5.0     1613
# 6.0     1488
# 3.0       23
# 2.0        1
# Name: count, dtype: int64
#
# cardiac
# No          24592
# Missing      2542
# Yes          1519
# Not done      147
# Name: count, dtype: int64
#
# hla_match_drb1_high
# 2.0    21418
# 1.0     7311
# 0.0       71
# Name: count, dtype: int64
#
# pulm_moderate
# No          21338
# Yes          5249
# Missing      2047
# Not done      166
# Name: count, dtype: int64
#
# hla_low_res_10
# 10.0    18798
# 5.0      3211
# 9.0      2544
# 6.0      1664
# 8.0      1387
# 7.0      1170
# 4.0        26
# Name: count, dtype: int64
#
# efs
# 1.0    15532
# 0.0    13268
# Name: count, dtype: int64
#
# efs_time
# 5.697     10
# 5.643     10
# 5.801      9
# 5.608      9
# 5.886      9
#           ..
# 4.430      1
# 19.391     1
# 23.336     1
# 36.169     1
# 25.158     1
# Name: count, Length: 19208, dtype: int64

# %% [markdown]
# # Simple NN

# %%
# Separate target and drop unneeded columns
y = train_data['efs']
X = train_data.drop(columns=['efs', 'efs_time', 'ID'], errors='ignore')

# Identify categorical and numerical columns
cat_cols = [col for col in X.columns if X[col].dtype=='object']
num_cols = [col for col in X.columns if pd.api.types.is_numeric_dtype(X[col])]

# For categorical: fill with "Missing" (if not already done)
for col in cat_cols:
    X[col].fillna('Missing', inplace=True)

# For numeric: fill with mode
for col in num_cols:
    if X[col].isna().any():
        X[col].fillna(X[col].median(), inplace=True)

# Encode categorical variables
X = pd.get_dummies(X, columns=cat_cols, dummy_na=False)

# Scale numeric featuers
scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])

# Ensure all numerica
X = X.astype(np.float32)


# Convert to NumPy arrays
X_array = X.values.astype(np.float32)
y_array = y.values.astype(np.float32)

# Split into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_array, y_array, test_size=0.2, random_state=42
)

# Convert NumPy arrays to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

# Create Datasets and Dataloaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
# Define a simple feedforward model
class SimpleNet(nn.Module):
    def __init__(self, input_dim):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)

        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.sigmoid(self.fc3(x))
        return x

# %%
# Initialize the model, loss, and optimizer
model = SimpleNet(input_dim=X_train.shape[1])
criterion = nn.BCELoss() # Binary cross-entropy loss
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop 
epochs = 100
for epoch in range(epochs):
    model.train()
    running_loss = 0.0

    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        outputs = outputs.view(-1) # Flatten for loss calculation
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
    epoch_loss = running_loss / len(train_loader.dataset)

    # Validation
    model.eval()
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, targets in val_loader:
            outputs = model(inputs).view(-1)
            preds = (outputs >= 0.5).float()
            val_correct += (preds==targets).sum().item()
            val_total += targets.size(0)
    val_accuracy = val_correct / val_total

    print(f"Epoch {epoch + 1}/{epochs}, Train Loss: {epoch_loss:.4f}, Val Acc: {val_accuracy:.4f}")
# Out:
# Epoch 1/100, Train Loss: 0.6072, Val Acc: 0.6807
# Epoch 2/100, Train Loss: 0.5911, Val Acc: 0.6773
# Epoch 3/100, Train Loss: 0.5866, Val Acc: 0.6813
# Epoch 4/100, Train Loss: 0.5826, Val Acc: 0.6844
# Epoch 5/100, Train Loss: 0.5763, Val Acc: 0.6806
# Epoch 6/100, Train Loss: 0.5699, Val Acc: 0.6802
# Epoch 7/100, Train Loss: 0.5609, Val Acc: 0.6717
# Epoch 8/100, Train Loss: 0.5527, Val Acc: 0.6701
# Epoch 9/100, Train Loss: 0.5417, Val Acc: 0.6729
# Epoch 10/100, Train Loss: 0.5321, Val Acc: 0.6701
# Epoch 11/100, Train Loss: 0.5212, Val Acc: 0.6693
# Epoch 12/100, Train Loss: 0.5112, Val Acc: 0.6674
# Epoch 13/100, Train Loss: 0.4983, Val Acc: 0.6517
# Epoch 14/100, Train Loss: 0.4872, Val Acc: 0.6559
# Epoch 15/100, Train Loss: 0.4775, Val Acc: 0.6611
# Epoch 16/100, Train Loss: 0.4661, Val Acc: 0.6556
# Epoch 17/100, Train Loss: 0.4544, Val Acc: 0.6536
# Epoch 18/100, Train Loss: 0.4458, Val Acc: 0.6524
# Epoch 19/100, Train Loss: 0.4368, Val Acc: 0.6528
# Epoch 20/100, Train Loss: 0.4247, Val Acc: 0.6483
# Epoch 21/100, Train Loss: 0.4152, Val Acc: 0.6420
# Epoch 22/100, Train Loss: 0.4056, Val Acc: 0.6474
# Epoch 23/100, Train Loss: 0.3975, Val Acc: 0.6312
# Epoch 24/100, Train Loss: 0.3889, Val Acc: 0.6276
# Epoch 25/100, Train Loss: 0.3791, Val Acc: 0.6382
# Epoch 26/100, Train Loss: 0.3732, Val Acc: 0.6264
# Epoch 27/100, Train Loss: 0.3667, Val Acc: 0.6403
# Epoch 28/100, Train Loss: 0.3583, Val Acc: 0.6424
# Epoch 29/100, Train Loss: 0.3499, Val Acc: 0.6328
# Epoch 30/100, Train Loss: 0.3436, Val Acc: 0.6351
# Epoch 31/100, Train Loss: 0.3386, Val Acc: 0.6276
# Epoch 32/100, Train Loss: 0.3316, Val Acc: 0.6300
# Epoch 33/100, Train Loss: 0.3263, Val Acc: 0.6361
# Epoch 34/100, Train Loss: 0.3183, Val Acc: 0.6280
# Epoch 35/100, Train Loss: 0.3126, Val Acc: 0.6283
# Epoch 36/100, Train Loss: 0.3073, Val Acc: 0.6281
# Epoch 37/100, Train Loss: 0.3035, Val Acc: 0.6307
# Epoch 38/100, Train Loss: 0.2951, Val Acc: 0.6288
# Epoch 39/100, Train Loss: 0.2910, Val Acc: 0.6273
# Epoch 40/100, Train Loss: 0.2867, Val Acc: 0.6234
# Epoch 41/100, Train Loss: 0.2835, Val Acc: 0.6252
# Epoch 42/100, Train Loss: 0.2788, Val Acc: 0.6127
# Epoch 43/100, Train Loss: 0.2728, Val Acc: 0.6177
# Epoch 44/100, Train Loss: 0.2702, Val Acc: 0.6148
# Epoch 45/100, Train Loss: 0.2677, Val Acc: 0.6245
# Epoch 46/100, Train Loss: 0.2624, Val Acc: 0.6188
# Epoch 47/100, Train Loss: 0.2579, Val Acc: 0.6148
# Epoch 48/100, Train Loss: 0.2512, Val Acc: 0.6233
# Epoch 49/100, Train Loss: 0.2497, Val Acc: 0.6200
# Epoch 50/100, Train Loss: 0.2518, Val Acc: 0.6142
# Epoch 51/100, Train Loss: 0.2433, Val Acc: 0.6146
# Epoch 52/100, Train Loss: 0.2389, Val Acc: 0.6073
# Epoch 53/100, Train Loss: 0.2354, Val Acc: 0.6168
# Epoch 54/100, Train Loss: 0.2357, Val Acc: 0.6149
# Epoch 55/100, Train Loss: 0.2331, Val Acc: 0.6156
# Epoch 56/100, Train Loss: 0.2340, Val Acc: 0.6189
# Epoch 57/100, Train Loss: 0.2217, Val Acc: 0.6189
# Epoch 58/100, Train Loss: 0.2227, Val Acc: 0.6172
# Epoch 59/100, Train Loss: 0.2202, Val Acc: 0.6155
# Epoch 60/100, Train Loss: 0.2206, Val Acc: 0.6177
# Epoch 61/100, Train Loss: 0.2168, Val Acc: 0.6122
# Epoch 62/100, Train Loss: 0.2090, Val Acc: 0.6217
# Epoch 63/100, Train Loss: 0.2108, Val Acc: 0.6161
# Epoch 64/100, Train Loss: 0.2050, Val Acc: 0.6165
# Epoch 65/100, Train Loss: 0.2041, Val Acc: 0.6109
# Epoch 66/100, Train Loss: 0.2005, Val Acc: 0.6182
# Epoch 67/100, Train Loss: 0.2010, Val Acc: 0.6087
# Epoch 68/100, Train Loss: 0.2038, Val Acc: 0.6123
# Epoch 69/100, Train Loss: 0.1930, Val Acc: 0.6127
# Epoch 70/100, Train Loss: 0.1946, Val Acc: 0.6123
# Epoch 71/100, Train Loss: 0.1935, Val Acc: 0.6135
# Epoch 72/100, Train Loss: 0.1885, Val Acc: 0.6075
# Epoch 73/100, Train Loss: 0.1806, Val Acc: 0.6146
# Epoch 74/100, Train Loss: 0.1910, Val Acc: 0.6066
# Epoch 75/100, Train Loss: 0.1814, Val Acc: 0.6010
# Epoch 76/100, Train Loss: 0.1809, Val Acc: 0.6128
# Epoch 77/100, Train Loss: 0.1796, Val Acc: 0.6036
# Epoch 78/100, Train Loss: 0.1749, Val Acc: 0.6087
# Epoch 79/100, Train Loss: 0.1706, Val Acc: 0.6075
# Epoch 80/100, Train Loss: 0.1720, Val Acc: 0.6073
# Epoch 81/100, Train Loss: 0.1720, Val Acc: 0.6125
# Epoch 82/100, Train Loss: 0.1694, Val Acc: 0.6141
# Epoch 83/100, Train Loss: 0.1688, Val Acc: 0.6165
# Epoch 84/100, Train Loss: 0.1659, Val Acc: 0.6102
# Epoch 85/100, Train Loss: 0.1616, Val Acc: 0.6089
# Epoch 86/100, Train Loss: 0.1643, Val Acc: 0.6122
# Epoch 87/100, Train Loss: 0.1624, Val Acc: 0.6104
# Epoch 88/100, Train Loss: 0.1652, Val Acc: 0.6099
# Epoch 89/100, Train Loss: 0.1574, Val Acc: 0.6189
# Epoch 90/100, Train Loss: 0.1543, Val Acc: 0.6047
# Epoch 91/100, Train Loss: 0.1477, Val Acc: 0.6132
# Epoch 92/100, Train Loss: 0.1576, Val Acc: 0.6120
# Epoch 93/100, Train Loss: 0.1491, Val Acc: 0.6012
# Epoch 94/100, Train Loss: 0.1484, Val Acc: 0.6078
# Epoch 95/100, Train Loss: 0.1479, Val Acc: 0.5988
# Epoch 96/100, Train Loss: 0.1476, Val Acc: 0.6142
# Epoch 97/100, Train Loss: 0.1458, Val Acc: 0.6078
# Epoch 98/100, Train Loss: 0.1404, Val Acc: 0.5983
# Epoch 99/100, Train Loss: 0.1434, Val Acc: 0.6095
# Epoch 100/100, Train Loss: 0.1477, Val Acc: 0.6111
